# %%
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from random import randint

# %%
num_clusters = 4

X = np.array([[0, 0]])

num_points = 10
for i in range(num_clusters):
    for j in range(num_points):
        X = np.vstack([X, [randint(0, randint(0, 1000)), randint(0, randint(0, 1000))]])


model = KMeans(n_clusters=num_clusters, random_state=0)

model.fit(X)

predictions = model.predict(X)
print("predictions:", predictions)
# Out:
# predictions: [0 1 3 0 3 3 0 3 0 0 3 2 3 1 1 0 0 3 2 1 2 1 1 1 1 0 3 3 3 0 2 1 1 2 3 0 0
#  3 2 1 0]

# %%
plt.scatter(X.T[0], X.T[1], c=predictions)
